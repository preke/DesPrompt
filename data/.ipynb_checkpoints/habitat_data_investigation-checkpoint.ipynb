# %%
import pandas as pd
import numpy as np

file_name = 'EAR Lensmodel Data.csv'

df = pd.read_csv(file_name)
df.head()
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-7-07615cf9359b> in <module>
#       4 file_name = 'EAR Lensmodel Data.csv'
#       5
# ----> 6 df = pd.read_excel(file_name)
#       7 df.head()
#
# ~/ENTER/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~/ENTER/lib/python3.8/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
# ...

# %%
test = pd.read_excel('original EAR transcripts/sub04.xls', header=1)
[i for i in test['Transcript'].values if not np.isnan(i)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-1fb19133a92f> in <module>
#       1 test = pd.read_excel('original EAR transcripts/sub04.xls', header=1)
# ----> 2 [i for i in test['Transcript'].values if not np.isnan(i)]
#
# <ipython-input-16-1fb19133a92f> in <listcomp>(.0)
#       1 test = pd.read_excel('original EAR transcripts/sub04.xls', header=1)
# ----> 2 [i for i in test['Transcript'].values if not np.isnan(i)]
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
